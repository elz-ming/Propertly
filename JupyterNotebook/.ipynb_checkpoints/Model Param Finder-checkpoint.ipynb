# %% [markdown]
# This notebook exists to mainly find out the best model used for prediction.

# %%
import pandas as pd

from sklearn.ensemble import GradientBoostingRegressor
from sklearn.tree import DecisionTreeRegressor

from sklearn.model_selection import train_test_split, GridSearchCV

from sklearn.metrics import r2_score, mean_absolute_error, mean_squared_error, mean_absolute_percentage_error

import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ### Gradient Boosting Regressor

# %%
gb_hyperparameters = {
    'n_estimators': [100,50],
    'max_depth': [10,5],
    'min_samples_leaf': [2],
    'min_samples_split': [2],
    'loss': ['squared_error'],
    'ccp_alpha': [0.0,0.1],
    'min_weight_fraction_leaf': [0.0,0.1],
    'validation_fraction': [0.2,0.25],
}

score = {
    'score':['train','test','R2','RMSE','MAE','MAPE']
}

# %% [markdown]
# A. Sale Data

# %%
df_train = pd.read_csv('../data/iProperty_sale_to_be_trained.csv')

df_train.drop(['name','psf','area'], axis=1, inplace=True)

for col in ['price']:
    q_low = df_train[col].quantile(0.01)
    q_hi  = df_train[col].quantile(0.99)
    df_train = df_train[(df_train[col] < q_hi) & (df_train[col] > q_low)]
    
one_hot = pd.get_dummies(df_train[['district','state','type','details']])
df_train = df_train.join(one_hot).drop(['district','state','type','details'], axis=1)

x = df_train.drop(['price'],axis=1)
y = df_train['price']

x_train, x_test, y_train, y_test = train_test_split(x,y,test_size=0.2)

# %%
gb = GradientBoostingRegressor()

gb.get_params()
# Out:
# {'alpha': 0.9,
#  'ccp_alpha': 0.0,
#  'criterion': 'friedman_mse',
#  'init': None,
#  'learning_rate': 0.1,
#  'loss': 'squared_error',
#  'max_depth': 3,
#  'max_features': None,
#  'max_leaf_nodes': None,
#  'min_impurity_decrease': 0.0,
#  'min_samples_leaf': 1,
#  'min_samples_split': 2,
#  'min_weight_fraction_leaf': 0.0,
#  'n_estimators': 100,
#  'n_iter_no_change': None,
#  'random_state': None,
#  'subsample': 1.0,
#  'tol': 0.0001,
#  'validation_fraction': 0.1,
#  'verbose': 0,
#  'warm_start': False}

# %%
model = GridSearchCV(estimator=gb, param_grid=gb_hyperparameters, cv=5, n_jobs=-1, verbose=4)
model.fit(x_train, y_train)
pd.DataFrame.from_dict(model.cv_results_).sort_values(['mean_test_score','std_test_score'],ascending=False).T
# Out:
# Fitting 5 folds for each of 32 candidates, totalling 160 fits
#                                                                                0   \
# mean_fit_time                                                           25.528013
# std_fit_time                                                             0.983774
# mean_score_time                                                          0.048004
# std_score_time                                                            0.01023
# param_ccp_alpha                                                               0.0
# param_loss                                                          squared_error
# param_max_depth                                                                10
# param_min_samples_leaf                                                          2
# param_min_samples_split                                                         2
# param_min_weight_fraction_leaf                                                0.0
# param_n_estimators                                                            100
# param_validation_fraction                                                     0.2
# params                          {'ccp_alpha': 0.0, 'loss': 'squared_error', 'm...
# split0_test_score                                                         0.76442
# split1_test_score                                                        0.751972
# split2_test_score                                                        0.794372
# split3_test_score                                                        0.754136
# split4_test_score                                                        0.754372
# mean_test_score                                                          0.763854
# std_test_score                                                           0.015857
# rank_test_score                                                                 1
#
#                                                                                1   \
# mean_fit_time                                                           25.019989
# std_fit_time                                                             0.986345
# mean_score_time                                                          0.040175
# std_score_time                                                            0.00817
# param_ccp_alpha                                                               0.0
# param_loss                                                          squared_error
# param_max_depth                                                                10
# param_min_samples_leaf                                                          2
# param_min_samples_split                                                         2
# param_min_weight_fraction_leaf                                                0.0
# param_n_estimators                                                            100
# param_validation_fraction                                                    0.25
# params                          {'ccp_alpha': 0.0, 'loss': 'squared_error', 'm...
# split0_test_score                                                        0.763675
# split1_test_score                                                        0.750805
# split2_test_score                                                        0.794267
# split3_test_score                                                        0.753498
# split4_test_score                                                        0.753668
# mean_test_score                                                          0.763183
# std_test_score                                                           0.016149
# rank_test_score                                                                 2
#
#                                                                                16  \
# mean_fit_time                                                           28.199648
# std_fit_time                                                             2.027129
# mean_score_time                                                          0.056417
# std_score_time                                                           0.012897
# param_ccp_alpha                                                               0.1
# param_loss                                                          squared_error
# param_max_depth                                                                10
# param_min_samples_leaf                                                          2
# param_min_samples_split                                                         2
# param_min_weight_fraction_leaf                                                0.0
# param_n_estimators                                                            100
# param_validation_fraction                                                     0.2
# params                          {'ccp_alpha': 0.1, 'loss': 'squared_error', 'm...
# split0_test_score                                                        0.764898
# split1_test_score                                                        0.750851
# split2_test_score                                                        0.793345
# split3_test_score                                                        0.752025
# split4_test_score                                                        0.754179
# mean_test_score                                                          0.763059
# std_test_score                                                           0.015939
# rank_test_score                                                                 3
#
#                                                                                17  \
# mean_fit_time                                                           26.077603
# std_fit_time                                                             1.020442
# mean_score_time                                                          0.052365
# std_score_time                                                           0.006205
# param_ccp_alpha                                                               0.1
# param_loss                                                          squared_error
# param_max_depth                                                                10
# param_min_samples_leaf                                                          2
# param_min_samples_split                                                         2
# param_min_weight_fraction_leaf                                                0.0
# param_n_estimators                                                            100
# param_validation_fraction                                                    0.25
# params                          {'ccp_alpha': 0.1, 'loss': 'squared_error', 'm...
# split0_test_score                                                         0.76403
# split1_test_score                                                        0.750036
# split2_test_score                                                        0.793628
# split3_test_score                                                        0.753996
# split4_test_score                                                        0.753388
# mean_test_score                                                          0.763016
# std_test_score                                                           0.016004
# rank_test_score                                                                 4
#
#                                                                                25  \
# mean_fit_time                                                           14.767718
# std_fit_time                                                             0.989159
# mean_score_time                                                          0.031896
# std_score_time                                                           0.000719
# param_ccp_alpha                                                               0.1
# param_loss                                                          squared_error
# param_max_depth                                                                 5
# param_min_samples_leaf                                                          2
# param_min_samples_split                                                         2
# param_min_weight_fraction_leaf                                                0.0
# param_n_estimators                                                            100
# param_validation_fraction                                                    0.25
# params                          {'ccp_alpha': 0.1, 'loss': 'squared_error', 'm...
# split0_test_score                                                        0.753414
# split1_test_score                                                        0.762707
# split2_test_score                                                        0.770086
# split3_test_score                                                        0.763413
# split4_test_score                                                        0.764535
# mean_test_score                                                          0.762831
# std_test_score                                                           0.005377
# rank_test_score                                                                 5
#
#                                                                                9   \
# mean_fit_time                                                           13.574942
# std_fit_time                                                             0.909472
# mean_score_time                                                          0.030994
# std_score_time                                                           0.003938
# param_ccp_alpha                                                               0.0
# param_loss                                                          squared_error
# param_max_depth                                                                 5
# param_min_samples_leaf                                                          2
# param_min_samples_split                                                         2
# param_min_weight_fraction_leaf                                                0.0
# param_n_estimators                                                            100
# param_validation_fraction                                                    0.25
# params                          {'ccp_alpha': 0.0, 'loss': 'squared_error', 'm...
# split0_test_score                                                        0.752848
# split1_test_score                                                         0.76219
# split2_test_score                                                        0.769829
# split3_test_score                                                        0.763738
# split4_test_score                                                        0.764286
# mean_test_score                                                          0.762578
# std_test_score                                                           0.005507
# rank_test_score                                                                 6
#
#                                                                                24  \
# mean_fit_time                                                           13.662036
# std_fit_time                                                             1.050853
# mean_score_time                                                          0.036173
# std_score_time                                                           0.006106
# param_ccp_alpha                                                               0.1
# param_loss                                                          squared_error
# param_max_depth                                                                 5
# param_min_samples_leaf                                                          2
# param_min_samples_split                                                         2
# param_min_weight_fraction_leaf                                                0.0
# param_n_estimators                                                            100
# param_validation_fraction                                                     0.2
# params                          {'ccp_alpha': 0.1, 'loss': 'squared_error', 'm...
# split0_test_score                                                        0.753047
# split1_test_score                                                        0.761817
# split2_test_score                                                        0.769749
# split3_test_score                                                        0.763798
# split4_test_score                                                        0.764202
# mean_test_score                                                          0.762522
# std_test_score                                                           0.005422
# rank_test_score                                                                 7
#
#                                                                                8   \
# mean_fit_time                                                            14.16536
# std_fit_time                                                             0.858533
# mean_score_time                                                          0.032008
# std_score_time                                                           0.009375
# param_ccp_alpha                                                               0.0
# param_loss                                                          squared_error
# param_max_depth                                                                 5
# param_min_samples_leaf                                                          2
# param_min_samples_split                                                         2
# param_min_weight_fraction_leaf                                                0.0
# param_n_estimators                                                            100
# param_validation_fraction                                                     0.2
# params                          {'ccp_alpha': 0.0, 'loss': 'squared_error', 'm...
# split0_test_score                                                        0.752161
# split1_test_score                                                        0.761957
# split2_test_score                                                        0.770613
# split3_test_score                                                        0.763097
# split4_test_score                                                        0.763512
# mean_test_score                                                          0.762268
# std_test_score                                                           0.005901
# rank_test_score                                                                 8
#
#                                                                                18  \
# mean_fit_time                                                           13.144272
# std_fit_time                                                             0.849623
# mean_score_time                                                          0.042167
# std_score_time                                                           0.013176
# param_ccp_alpha                                                               0.1
# param_loss                                                          squared_error
# param_max_depth                                                                10
# param_min_samples_leaf                                                          2
# param_min_samples_split                                                         2
# param_min_weight_fraction_leaf                                                0.0
# param_n_estimators                                                             50
# param_validation_fraction                                                     0.2
# params                          {'ccp_alpha': 0.1, 'loss': 'squared_error', 'm...
# split0_test_score                                                        0.760926
# split1_test_score                                                        0.743374
# split2_test_score                                                        0.788288
# split3_test_score                                                         0.74699
# split4_test_score                                                        0.745838
# mean_test_score                                                          0.757083
# std_test_score                                                           0.016762
# rank_test_score                                                                 9
#
#                                                                                2   \
# mean_fit_time                                                           12.484694
# std_fit_time                                                             0.310498
# mean_score_time                                                          0.034296
# std_score_time                                                           0.004459
# param_ccp_alpha                                                               0.0
# param_loss                                                          squared_error
# param_max_depth                                                                10
# param_min_samples_leaf                                                          2
# param_min_samples_split                                                         2
# param_min_weight_fraction_leaf                                                0.0
# param_n_estimators                                                             50
# param_validation_fraction                                                     0.2
# params                          {'ccp_alpha': 0.0, 'loss': 'squared_error', 'm...
# split0_test_score                                                         0.75986
# split1_test_score                                                        0.744638
# split2_test_score                                                        0.786551
# split3_test_score                                                        0.747788
# split4_test_score                                                        0.746331
# mean_test_score                                                          0.757034
# std_test_score                                                           0.015703
# rank_test_score                                                                10
#
#                                 ...  \
# mean_fit_time                   ...
# std_fit_time                    ...
# mean_score_time                 ...
# std_score_time                  ...
# param_ccp_alpha                 ...
# param_loss                      ...
# param_max_depth                 ...
# param_min_samples_leaf          ...
# param_min_samples_split         ...
# param_min_weight_fraction_leaf  ...
# param_n_estimators              ...
# param_validation_fraction       ...
# params                          ...
# split0_test_score               ...
# split1_test_score               ...
# split2_test_score               ...
# split3_test_score               ...
# split4_test_score               ...
# mean_test_score                 ...
# std_test_score                  ...
# rank_test_score                 ...
#
#                                                                                21  \
# mean_fit_time                                                           10.774367
# std_fit_time                                                             0.443965
# mean_score_time                                                          0.038071
# std_score_time                                                           0.006317
# param_ccp_alpha                                                               0.1
# param_loss                                                          squared_error
# param_max_depth                                                                10
# param_min_samples_leaf                                                          2
# param_min_samples_split                                                         2
# param_min_weight_fraction_leaf                                                0.1
# param_n_estimators                                                            100
# param_validation_fraction                                                    0.25
# params                          {'ccp_alpha': 0.1, 'loss': 'squared_error', 'm...
# split0_test_score                                                        0.587475
# split1_test_score                                                        0.600557
# split2_test_score                                                        0.600015
# split3_test_score                                                        0.631477
# split4_test_score                                                        0.600223
# mean_test_score                                                           0.60395
# std_test_score                                                           0.014629
# rank_test_score                                                                23
#
#                                                                                4   \
# mean_fit_time                                                           10.973449
# std_fit_time                                                             0.891646
# mean_score_time                                                          0.033423
# std_score_time                                                           0.002763
# param_ccp_alpha                                                               0.0
# param_loss                                                          squared_error
# param_max_depth                                                                10
# param_min_samples_leaf                                                          2
# param_min_samples_split                                                         2
# param_min_weight_fraction_leaf                                                0.1
# param_n_estimators                                                            100
# param_validation_fraction                                                     0.2
# params                          {'ccp_alpha': 0.0, 'loss': 'squared_error', 'm...
# split0_test_score                                                        0.587475
# split1_test_score                                                        0.600557
# split2_test_score                                                        0.600015
# split3_test_score                                                        0.631477
# split4_test_score                                                        0.600223
# mean_test_score                                                           0.60395
# std_test_score                                                           0.014629
# rank_test_score                                                                23
#
#                                                                                22  \
# mean_fit_time                                                            5.484637
# std_fit_time                                                             0.442702
# mean_score_time                                                          0.025965
# std_score_time                                                           0.007674
# param_ccp_alpha                                                               0.1
# param_loss                                                          squared_error
# param_max_depth                                                                10
# param_min_samples_leaf                                                          2
# param_min_samples_split                                                         2
# param_min_weight_fraction_leaf                                                0.1
# param_n_estimators                                                             50
# param_validation_fraction                                                     0.2
# params                          {'ccp_alpha': 0.1, 'loss': 'squared_error', 'm...
# split0_test_score                                                        0.564512
# split1_test_score                                                        0.574356
# split2_test_score                                                        0.575603
# split3_test_score                                                         0.60895
# split4_test_score                                                        0.582398
# mean_test_score                                                          0.581164
# std_test_score                                                           0.015021
# rank_test_score                                                                25
#
#                                                                                7   \
# mean_fit_time                                                            5.812857
# std_fit_time                                                             0.655245
# mean_score_time                                                          0.025528
# std_score_time                                                           0.009565
# param_ccp_alpha                                                               0.0
# param_loss                                                          squared_error
# param_max_depth                                                                10
# param_min_samples_leaf                                                          2
# param_min_samples_split                                                         2
# param_min_weight_fraction_leaf                                                0.1
# param_n_estimators                                                             50
# param_validation_fraction                                                    0.25
# params                          {'ccp_alpha': 0.0, 'loss': 'squared_error', 'm...
# split0_test_score                                                        0.564512
# split1_test_score                                                        0.574356
# split2_test_score                                                        0.575603
# split3_test_score                                                         0.60895
# split4_test_score                                                        0.582398
# mean_test_score                                                          0.581164
# std_test_score                                                           0.015021
# rank_test_score                                                                25
#
#                                                                                6   \
# mean_fit_time                                                            5.904327
# std_fit_time                                                             0.536808
# mean_score_time                                                           0.03311
# std_score_time                                                           0.009831
# param_ccp_alpha                                                               0.0
# param_loss                                                          squared_error
# param_max_depth                                                                10
# param_min_samples_leaf                                                          2
# param_min_samples_split                                                         2
# param_min_weight_fraction_leaf                                                0.1
# param_n_estimators                                                             50
# param_validation_fraction                                                     0.2
# params                          {'ccp_alpha': 0.0, 'loss': 'squared_error', 'm...
# split0_test_score                                                        0.564512
# split1_test_score                                                        0.574356
# split2_test_score                                                        0.575603
# split3_test_score                                                         0.60895
# split4_test_score                                                        0.582398
# mean_test_score                                                          0.581164
# std_test_score                                                           0.015021
# rank_test_score                                                                25
#
#                                                                                23  \
# mean_fit_time                                                            5.481648
# std_fit_time                                                              0.27581
# mean_score_time                                                          0.035102
# std_score_time                                                           0.003969
# param_ccp_alpha                                                               0.1
# param_loss                                                          squared_error
# param_max_depth                                                                10
# param_min_samples_leaf                                                          2
# param_min_samples_split                                                         2
# param_min_weight_fraction_leaf                                                0.1
# param_n_estimators                                                             50
# param_validation_fraction                                                    0.25
# params                          {'ccp_alpha': 0.1, 'loss': 'squared_error', 'm...
# split0_test_score                                                        0.564512
# split1_test_score                                                        0.574356
# split2_test_score                                                        0.575603
# split3_test_score                                                         0.60895
# split4_test_score                                                        0.582398
# mean_test_score                                                          0.581164
# std_test_score                                                           0.015021
# rank_test_score                                                                28
#
#                                                                                31  \
# mean_fit_time                                                            4.799541
# std_fit_time                                                             0.222494
# mean_score_time                                                           0.01805
# std_score_time                                                           0.004825
# param_ccp_alpha                                                               0.1
# param_loss                                                          squared_error
# param_max_depth                                                                 5
# param_min_samples_leaf                                                          2
# param_min_samples_split                                                         2
# param_min_weight_fraction_leaf                                                0.1
# param_n_estimators                                                             50
# param_validation_fraction                                                    0.25
# params                          {'ccp_alpha': 0.1, 'loss': 'squared_error', 'm...
# split0_test_score                                                        0.564627
# split1_test_score                                                        0.574279
# split2_test_score                                                        0.574979
# split3_test_score                                                        0.608633
# split4_test_score                                                         0.58218
# mean_test_score                                                           0.58094
# std_test_score                                                            0.01493
# rank_test_score                                                                29
#
#                                                                                14  \
# mean_fit_time                                                            5.096935
# std_fit_time                                                             0.203455
# mean_score_time                                                           0.02452
# std_score_time                                                           0.008071
# param_ccp_alpha                                                               0.0
# param_loss                                                          squared_error
# param_max_depth                                                                 5
# param_min_samples_leaf                                                          2
# param_min_samples_split                                                         2
# param_min_weight_fraction_leaf                                                0.1
# param_n_estimators                                                             50
# param_validation_fraction                                                     0.2
# params                          {'ccp_alpha': 0.0, 'loss': 'squared_error', 'm...
# split0_test_score                                                        0.564627
# split1_test_score                                                        0.574279
# split2_test_score                                                        0.574979
# split3_test_score                                                        0.608633
# split4_test_score                                                         0.58218
# mean_test_score                                                           0.58094
# std_test_score                                                            0.01493
# rank_test_score                                                                29
#
#                                                                                30  \
# mean_fit_time                                                            5.468782
# std_fit_time                                                             0.381781
# mean_score_time                                                          0.028557
# std_score_time                                                           0.006448
# param_ccp_alpha                                                               0.1
# param_loss                                                          squared_error
# param_max_depth                                                                 5
# param_min_samples_leaf                                                          2
# param_min_samples_split                                                         2
# param_min_weight_fraction_leaf                                                0.1
# param_n_estimators                                                             50
# param_validation_fraction                                                     0.2
# params                          {'ccp_alpha': 0.1, 'loss': 'squared_error', 'm...
# split0_test_score                                                        0.564627
# split1_test_score                                                        0.574279
# split2_test_score                                                        0.574979
# split3_test_score                                                        0.608633
# split4_test_score                                                         0.58218
# mean_test_score                                                           0.58094
# std_test_score                                                            0.01493
# rank_test_score                                                                31
#
#                                                                                15
# mean_fit_time                                                            5.347183
# std_fit_time                                                             0.316216
# mean_score_time                                                          0.029165
# std_score_time                                                           0.006798
# param_ccp_alpha                                                               0.0
# param_loss                                                          squared_error
# param_max_depth                                                                 5
# param_min_samples_leaf                                                          2
# param_min_samples_split                                                         2
# param_min_weight_fraction_leaf                                                0.1
# param_n_estimators                                                             50
# param_validation_fraction                                                    0.25
# params                          {'ccp_alpha': 0.0, 'loss': 'squared_error', 'm...
# split0_test_score                                                        0.564627
# split1_test_score                                                        0.574279
# split2_test_score                                                        0.574979
# split3_test_score                                                        0.608633
# split4_test_score                                                         0.58218
# mean_test_score                                                           0.58094
# std_test_score                                                            0.01493
# rank_test_score                                                                31
#
# [21 rows x 32 columns]

# %%
gb_best_params = model.best_params_

gb_best_params
# Out:
# {'ccp_alpha': 0.0,
#  'loss': 'squared_error',
#  'max_depth': 10,
#  'min_samples_leaf': 2,
#  'min_samples_split': 2,
#  'min_weight_fraction_leaf': 0.0,
#  'n_estimators': 100,
#  'validation_fraction': 0.2}

# %%
key = 'SALE'

gb = GradientBoostingRegressor()
gb.set_params(**gb_best_params)
gb.fit(x_train,y_train)
y_pred = gb.predict(x_test)

score[key] = []
score[key].append(gb.score(x_train,y_train))
score[key].append(gb.score(x_test,y_test))
score[key].append(r2_score(y_test,y_pred))
score[key].append(mean_squared_error(y_test,y_pred, squared=False))
score[key].append(mean_absolute_error(y_test,y_pred))
score[key].append(mean_absolute_percentage_error(y_test,y_pred))

# %%
score
# Out:
# {'score': ['train', 'test', 'R2', 'RMSE', 'MAE', 'MAPE'],
#  'SALE': [0.9193965566250999,
#   0.785240086338416,
#   0.785240086338416,
#   473110.0373973638,
#   257184.9235693283,
#   0.26293963159570116]}

# %% [markdown]
# B. Rent Data

# %%
df_train = pd.read_csv('../data/iProperty_rent_to_be_trained.csv')

df_train.drop(['name','psf','area'], axis=1, inplace=True)

for col in ['price']:
    q_low = df_train[col].quantile(0.01)
    q_hi  = df_train[col].quantile(0.99)
    df_train = df_train[(df_train[col] < q_hi) & (df_train[col] > q_low)]
    
one_hot = pd.get_dummies(df_train[['district','state','type','details']])
df_train = df_train.join(one_hot).drop(['district','state','type','details'], axis=1)

# %%
gb = GradientBoostingRegressor()

gb.get_params()
# Out:
# {'alpha': 0.9,
#  'ccp_alpha': 0.0,
#  'criterion': 'friedman_mse',
#  'init': None,
#  'learning_rate': 0.1,
#  'loss': 'squared_error',
#  'max_depth': 3,
#  'max_features': None,
#  'max_leaf_nodes': None,
#  'min_impurity_decrease': 0.0,
#  'min_samples_leaf': 1,
#  'min_samples_split': 2,
#  'min_weight_fraction_leaf': 0.0,
#  'n_estimators': 100,
#  'n_iter_no_change': None,
#  'random_state': None,
#  'subsample': 1.0,
#  'tol': 0.0001,
#  'validation_fraction': 0.1,
#  'verbose': 0,
#  'warm_start': False}

# %%
model = GridSearchCV(estimator=gb, param_grid=gb_hyperparameters, cv=5, n_jobs=-1, verbose=4)
model.fit(x_train, y_train)
pd.DataFrame.from_dict(model.cv_results_).sort_values(['mean_test_score','std_test_score'],ascending=False).T
# Out:
# Fitting 5 folds for each of 32 candidates, totalling 160 fits
#                                                                                0   \
# mean_fit_time                                                            24.64163
# std_fit_time                                                             0.372101
# mean_score_time                                                          0.044477
# std_score_time                                                           0.005627
# param_ccp_alpha                                                               0.0
# param_loss                                                          squared_error
# param_max_depth                                                                10
# param_min_samples_leaf                                                          2
# param_min_samples_split                                                         2
# param_min_weight_fraction_leaf                                                0.0
# param_n_estimators                                                            100
# param_validation_fraction                                                     0.2
# params                          {'ccp_alpha': 0.0, 'loss': 'squared_error', 'm...
# split0_test_score                                                        0.764783
# split1_test_score                                                        0.751925
# split2_test_score                                                        0.792379
# split3_test_score                                                        0.754171
# split4_test_score                                                        0.755407
# mean_test_score                                                          0.763733
# std_test_score                                                           0.014979
# rank_test_score                                                                 1
#
#                                                                                16  \
# mean_fit_time                                                           26.371591
# std_fit_time                                                             1.801728
# mean_score_time                                                          0.047872
# std_score_time                                                             0.0131
# param_ccp_alpha                                                               0.1
# param_loss                                                          squared_error
# param_max_depth                                                                10
# param_min_samples_leaf                                                          2
# param_min_samples_split                                                         2
# param_min_weight_fraction_leaf                                                0.0
# param_n_estimators                                                            100
# param_validation_fraction                                                     0.2
# params                          {'ccp_alpha': 0.1, 'loss': 'squared_error', 'm...
# split0_test_score                                                        0.764556
# split1_test_score                                                        0.752443
# split2_test_score                                                        0.794359
# split3_test_score                                                        0.752678
# split4_test_score                                                        0.754075
# mean_test_score                                                          0.763622
# std_test_score                                                            0.01601
# rank_test_score                                                                 2
#
#                                                                                1   \
# mean_fit_time                                                            24.80509
# std_fit_time                                                             0.143489
# mean_score_time                                                          0.053438
# std_score_time                                                           0.004048
# param_ccp_alpha                                                               0.0
# param_loss                                                          squared_error
# param_max_depth                                                                10
# param_min_samples_leaf                                                          2
# param_min_samples_split                                                         2
# param_min_weight_fraction_leaf                                                0.0
# param_n_estimators                                                            100
# param_validation_fraction                                                    0.25
# params                          {'ccp_alpha': 0.0, 'loss': 'squared_error', 'm...
# split0_test_score                                                        0.763547
# split1_test_score                                                        0.750875
# split2_test_score                                                        0.792749
# split3_test_score                                                        0.754168
# split4_test_score                                                        0.754795
# mean_test_score                                                          0.763227
# std_test_score                                                           0.015345
# rank_test_score                                                                 3
#
#                                                                                17  \
# mean_fit_time                                                           25.515549
# std_fit_time                                                             1.447609
# mean_score_time                                                          0.051656
# std_score_time                                                           0.006557
# param_ccp_alpha                                                               0.1
# param_loss                                                          squared_error
# param_max_depth                                                                10
# param_min_samples_leaf                                                          2
# param_min_samples_split                                                         2
# param_min_weight_fraction_leaf                                                0.0
# param_n_estimators                                                            100
# param_validation_fraction                                                    0.25
# params                          {'ccp_alpha': 0.1, 'loss': 'squared_error', 'm...
# split0_test_score                                                        0.764338
# split1_test_score                                                        0.749768
# split2_test_score                                                        0.794485
# split3_test_score                                                        0.753745
# split4_test_score                                                        0.753325
# mean_test_score                                                          0.763132
# std_test_score                                                           0.016416
# rank_test_score                                                                 4
#
#                                                                                8   \
# mean_fit_time                                                           13.236982
# std_fit_time                                                             0.291984
# mean_score_time                                                          0.029545
# std_score_time                                                           0.004747
# param_ccp_alpha                                                               0.0
# param_loss                                                          squared_error
# param_max_depth                                                                 5
# param_min_samples_leaf                                                          2
# param_min_samples_split                                                         2
# param_min_weight_fraction_leaf                                                0.0
# param_n_estimators                                                            100
# param_validation_fraction                                                     0.2
# params                          {'ccp_alpha': 0.0, 'loss': 'squared_error', 'm...
# split0_test_score                                                        0.753397
# split1_test_score                                                        0.761973
# split2_test_score                                                        0.770562
# split3_test_score                                                        0.763165
# split4_test_score                                                        0.764194
# mean_test_score                                                          0.762658
# std_test_score                                                           0.005502
# rank_test_score                                                                 5
#
#                                                                                9   \
# mean_fit_time                                                           13.180842
# std_fit_time                                                             0.382457
# mean_score_time                                                           0.03214
# std_score_time                                                           0.000801
# param_ccp_alpha                                                               0.0
# param_loss                                                          squared_error
# param_max_depth                                                                 5
# param_min_samples_leaf                                                          2
# param_min_samples_split                                                         2
# param_min_weight_fraction_leaf                                                0.0
# param_n_estimators                                                            100
# param_validation_fraction                                                    0.25
# params                          {'ccp_alpha': 0.0, 'loss': 'squared_error', 'm...
# split0_test_score                                                        0.753079
# split1_test_score                                                        0.762087
# split2_test_score                                                        0.770107
# split3_test_score                                                        0.764169
# split4_test_score                                                        0.763829
# mean_test_score                                                          0.762654
# std_test_score                                                             0.0055
# rank_test_score                                                                 6
#
#                                                                                25  \
# mean_fit_time                                                           14.999228
# std_fit_time                                                             1.198674
# mean_score_time                                                          0.035462
# std_score_time                                                           0.006041
# param_ccp_alpha                                                               0.1
# param_loss                                                          squared_error
# param_max_depth                                                                 5
# param_min_samples_leaf                                                          2
# param_min_samples_split                                                         2
# param_min_weight_fraction_leaf                                                0.0
# param_n_estimators                                                            100
# param_validation_fraction                                                    0.25
# params                          {'ccp_alpha': 0.1, 'loss': 'squared_error', 'm...
# split0_test_score                                                        0.753192
# split1_test_score                                                        0.762514
# split2_test_score                                                        0.769892
# split3_test_score                                                        0.763365
# split4_test_score                                                        0.763679
# mean_test_score                                                          0.762528
# std_test_score                                                           0.005356
# rank_test_score                                                                 7
#
#                                                                                24  \
# mean_fit_time                                                           13.846317
# std_fit_time                                                             1.334111
# mean_score_time                                                          0.032464
# std_score_time                                                           0.000559
# param_ccp_alpha                                                               0.1
# param_loss                                                          squared_error
# param_max_depth                                                                 5
# param_min_samples_leaf                                                          2
# param_min_samples_split                                                         2
# param_min_weight_fraction_leaf                                                0.0
# param_n_estimators                                                            100
# param_validation_fraction                                                     0.2
# params                          {'ccp_alpha': 0.1, 'loss': 'squared_error', 'm...
# split0_test_score                                                          0.7531
# split1_test_score                                                        0.761413
# split2_test_score                                                        0.769715
# split3_test_score                                                         0.76376
# split4_test_score                                                        0.763609
# mean_test_score                                                          0.762319
# std_test_score                                                           0.005372
# rank_test_score                                                                 8
#
#                                                                                2   \
# mean_fit_time                                                           12.449634
# std_fit_time                                                             0.434993
# mean_score_time                                                          0.041131
# std_score_time                                                           0.012996
# param_ccp_alpha                                                               0.0
# param_loss                                                          squared_error
# param_max_depth                                                                10
# param_min_samples_leaf                                                          2
# param_min_samples_split                                                         2
# param_min_weight_fraction_leaf                                                0.0
# param_n_estimators                                                             50
# param_validation_fraction                                                     0.2
# params                          {'ccp_alpha': 0.0, 'loss': 'squared_error', 'm...
# split0_test_score                                                        0.760454
# split1_test_score                                                        0.744128
# split2_test_score                                                        0.787681
# split3_test_score                                                        0.747221
# split4_test_score                                                        0.744694
# mean_test_score                                                          0.756835
# std_test_score                                                           0.016528
# rank_test_score                                                                 9
#
#                                                                                18  \
# mean_fit_time                                                            13.07021
# std_fit_time                                                             0.885977
# mean_score_time                                                          0.043119
# std_score_time                                                           0.013477
# param_ccp_alpha                                                               0.1
# param_loss                                                          squared_error
# param_max_depth                                                                10
# param_min_samples_leaf                                                          2
# param_min_samples_split                                                         2
# param_min_weight_fraction_leaf                                                0.0
# param_n_estimators                                                             50
# param_validation_fraction                                                     0.2
# params                          {'ccp_alpha': 0.1, 'loss': 'squared_error', 'm...
# split0_test_score                                                        0.759787
# split1_test_score                                                        0.743304
# split2_test_score                                                        0.787753
# split3_test_score                                                        0.746636
# split4_test_score                                                        0.746263
# mean_test_score                                                          0.756749
# std_test_score                                                           0.016513
# rank_test_score                                                                10
#
#                                 ...  \
# mean_fit_time                   ...
# std_fit_time                    ...
# mean_score_time                 ...
# std_score_time                  ...
# param_ccp_alpha                 ...
# param_loss                      ...
# param_max_depth                 ...
# param_min_samples_leaf          ...
# param_min_samples_split         ...
# param_min_weight_fraction_leaf  ...
# param_n_estimators              ...
# param_validation_fraction       ...
# params                          ...
# split0_test_score               ...
# split1_test_score               ...
# split2_test_score               ...
# split3_test_score               ...
# split4_test_score               ...
# mean_test_score                 ...
# std_test_score                  ...
# rank_test_score                 ...
#
#                                                                                21  \
# mean_fit_time                                                           10.486832
# std_fit_time                                                             0.713234
# mean_score_time                                                          0.032424
# std_score_time                                                           0.009904
# param_ccp_alpha                                                               0.1
# param_loss                                                          squared_error
# param_max_depth                                                                10
# param_min_samples_leaf                                                          2
# param_min_samples_split                                                         2
# param_min_weight_fraction_leaf                                                0.1
# param_n_estimators                                                            100
# param_validation_fraction                                                    0.25
# params                          {'ccp_alpha': 0.1, 'loss': 'squared_error', 'm...
# split0_test_score                                                        0.587475
# split1_test_score                                                        0.600557
# split2_test_score                                                        0.600015
# split3_test_score                                                        0.631477
# split4_test_score                                                        0.600223
# mean_test_score                                                           0.60395
# std_test_score                                                           0.014629
# rank_test_score                                                                21
#
#                                                                                20  \
# mean_fit_time                                                           10.723005
# std_fit_time                                                             0.190034
# mean_score_time                                                          0.035923
# std_score_time                                                           0.007142
# param_ccp_alpha                                                               0.1
# param_loss                                                          squared_error
# param_max_depth                                                                10
# param_min_samples_leaf                                                          2
# param_min_samples_split                                                         2
# param_min_weight_fraction_leaf                                                0.1
# param_n_estimators                                                            100
# param_validation_fraction                                                     0.2
# params                          {'ccp_alpha': 0.1, 'loss': 'squared_error', 'm...
# split0_test_score                                                        0.587475
# split1_test_score                                                        0.600557
# split2_test_score                                                        0.600015
# split3_test_score                                                        0.631477
# split4_test_score                                                        0.600223
# mean_test_score                                                           0.60395
# std_test_score                                                           0.014629
# rank_test_score                                                                21
#
#                                                                                7   \
# mean_fit_time                                                            5.267373
# std_fit_time                                                              0.22615
# mean_score_time                                                          0.020619
# std_score_time                                                           0.005929
# param_ccp_alpha                                                               0.0
# param_loss                                                          squared_error
# param_max_depth                                                                10
# param_min_samples_leaf                                                          2
# param_min_samples_split                                                         2
# param_min_weight_fraction_leaf                                                0.1
# param_n_estimators                                                             50
# param_validation_fraction                                                    0.25
# params                          {'ccp_alpha': 0.0, 'loss': 'squared_error', 'm...
# split0_test_score                                                        0.564512
# split1_test_score                                                        0.574356
# split2_test_score                                                        0.575603
# split3_test_score                                                         0.60895
# split4_test_score                                                        0.582398
# mean_test_score                                                          0.581164
# std_test_score                                                           0.015021
# rank_test_score                                                                25
#
#                                                                                6   \
# mean_fit_time                                                            5.051268
# std_fit_time                                                             0.049179
# mean_score_time                                                          0.026922
# std_score_time                                                           0.008344
# param_ccp_alpha                                                               0.0
# param_loss                                                          squared_error
# param_max_depth                                                                10
# param_min_samples_leaf                                                          2
# param_min_samples_split                                                         2
# param_min_weight_fraction_leaf                                                0.1
# param_n_estimators                                                             50
# param_validation_fraction                                                     0.2
# params                          {'ccp_alpha': 0.0, 'loss': 'squared_error', 'm...
# split0_test_score                                                        0.564512
# split1_test_score                                                        0.574356
# split2_test_score                                                        0.575603
# split3_test_score                                                         0.60895
# split4_test_score                                                        0.582398
# mean_test_score                                                          0.581164
# std_test_score                                                           0.015021
# rank_test_score                                                                25
#
#                                                                                22  \
# mean_fit_time                                                            5.762976
# std_fit_time                                                             0.500539
# mean_score_time                                                          0.032893
# std_score_time                                                             0.0115
# param_ccp_alpha                                                               0.1
# param_loss                                                          squared_error
# param_max_depth                                                                10
# param_min_samples_leaf                                                          2
# param_min_samples_split                                                         2
# param_min_weight_fraction_leaf                                                0.1
# param_n_estimators                                                             50
# param_validation_fraction                                                     0.2
# params                          {'ccp_alpha': 0.1, 'loss': 'squared_error', 'm...
# split0_test_score                                                        0.564512
# split1_test_score                                                        0.574356
# split2_test_score                                                        0.575603
# split3_test_score                                                         0.60895
# split4_test_score                                                        0.582398
# mean_test_score                                                          0.581164
# std_test_score                                                           0.015021
# rank_test_score                                                                25
#
#                                                                                23  \
# mean_fit_time                                                            5.290581
# std_fit_time                                                             0.189357
# mean_score_time                                                          0.019656
# std_score_time                                                           0.006702
# param_ccp_alpha                                                               0.1
# param_loss                                                          squared_error
# param_max_depth                                                                10
# param_min_samples_leaf                                                          2
# param_min_samples_split                                                         2
# param_min_weight_fraction_leaf                                                0.1
# param_n_estimators                                                             50
# param_validation_fraction                                                    0.25
# params                          {'ccp_alpha': 0.1, 'loss': 'squared_error', 'm...
# split0_test_score                                                        0.564512
# split1_test_score                                                        0.574356
# split2_test_score                                                        0.575603
# split3_test_score                                                         0.60895
# split4_test_score                                                        0.582398
# mean_test_score                                                          0.581164
# std_test_score                                                           0.015021
# rank_test_score                                                                25
#
#                                                                                30  \
# mean_fit_time                                                             5.39034
# std_fit_time                                                             0.428521
# mean_score_time                                                          0.029234
# std_score_time                                                           0.011762
# param_ccp_alpha                                                               0.1
# param_loss                                                          squared_error
# param_max_depth                                                                 5
# param_min_samples_leaf                                                          2
# param_min_samples_split                                                         2
# param_min_weight_fraction_leaf                                                0.1
# param_n_estimators                                                             50
# param_validation_fraction                                                     0.2
# params                          {'ccp_alpha': 0.1, 'loss': 'squared_error', 'm...
# split0_test_score                                                        0.564627
# split1_test_score                                                        0.574279
# split2_test_score                                                        0.574979
# split3_test_score                                                        0.608633
# split4_test_score                                                         0.58218
# mean_test_score                                                           0.58094
# std_test_score                                                            0.01493
# rank_test_score                                                                29
#
#                                                                                31  \
# mean_fit_time                                                            4.794727
# std_fit_time                                                             0.688844
# mean_score_time                                                           0.02083
# std_score_time                                                           0.006643
# param_ccp_alpha                                                               0.1
# param_loss                                                          squared_error
# param_max_depth                                                                 5
# param_min_samples_leaf                                                          2
# param_min_samples_split                                                         2
# param_min_weight_fraction_leaf                                                0.1
# param_n_estimators                                                             50
# param_validation_fraction                                                    0.25
# params                          {'ccp_alpha': 0.1, 'loss': 'squared_error', 'm...
# split0_test_score                                                        0.564627
# split1_test_score                                                        0.574279
# split2_test_score                                                        0.574979
# split3_test_score                                                        0.608633
# split4_test_score                                                         0.58218
# mean_test_score                                                           0.58094
# std_test_score                                                            0.01493
# rank_test_score                                                                29
#
#                                                                                14  \
# mean_fit_time                                                            5.322885
# std_fit_time                                                             0.440159
# mean_score_time                                                          0.031793
# std_score_time                                                           0.017174
# param_ccp_alpha                                                               0.0
# param_loss                                                          squared_error
# param_max_depth                                                                 5
# param_min_samples_leaf                                                          2
# param_min_samples_split                                                         2
# param_min_weight_fraction_leaf                                                0.1
# param_n_estimators                                                             50
# param_validation_fraction                                                     0.2
# params                          {'ccp_alpha': 0.0, 'loss': 'squared_error', 'm...
# split0_test_score                                                        0.564627
# split1_test_score                                                        0.574279
# split2_test_score                                                        0.574979
# split3_test_score                                                        0.608633
# split4_test_score                                                         0.58218
# mean_test_score                                                           0.58094
# std_test_score                                                            0.01493
# rank_test_score                                                                31
#
#                                                                                15
# mean_fit_time                                                             5.41567
# std_fit_time                                                             0.185648
# mean_score_time                                                          0.032327
# std_score_time                                                           0.000651
# param_ccp_alpha                                                               0.0
# param_loss                                                          squared_error
# param_max_depth                                                                 5
# param_min_samples_leaf                                                          2
# param_min_samples_split                                                         2
# param_min_weight_fraction_leaf                                                0.1
# param_n_estimators                                                             50
# param_validation_fraction                                                    0.25
# params                          {'ccp_alpha': 0.0, 'loss': 'squared_error', 'm...
# split0_test_score                                                        0.564627
# split1_test_score                                                        0.574279
# split2_test_score                                                        0.574979
# split3_test_score                                                        0.608633
# split4_test_score                                                         0.58218
# mean_test_score                                                           0.58094
# std_test_score                                                            0.01493
# rank_test_score                                                                31
#
# [21 rows x 32 columns]

# %%
gb_best_params = model.best_params_

gb_best_params
# Out:
# {'ccp_alpha': 0.0,
#  'loss': 'squared_error',
#  'max_depth': 10,
#  'min_samples_leaf': 2,
#  'min_samples_split': 2,
#  'min_weight_fraction_leaf': 0.0,
#  'n_estimators': 100,
#  'validation_fraction': 0.2}

# %%
key = 'RENT'

gb = GradientBoostingRegressor()
gb.set_params(**gb_best_params)
gb.fit(x_train,y_train)
y_pred = gb.predict(x_test)

score[key] = []
score[key].append(gb.score(x_train,y_train))
score[key].append(gb.score(x_test,y_test))
score[key].append(r2_score(y_test,y_pred))
score[key].append(mean_squared_error(y_test,y_pred, squared=False))
score[key].append(mean_absolute_error(y_test,y_pred))
score[key].append(mean_absolute_percentage_error(y_test,y_pred))

# %% [markdown]
# Display

# %%
score_df = pd.DataFrame(score).T
score_df.columns = score_df.iloc[0]
score_df = score_df[1:]
score_df = score_df.reset_index()
score_df.rename(columns={'index':'data'}, inplace=True)
score_df
# Out:
# score  data     train     test       R2           RMSE            MAE  \
# 0      SALE  0.919397  0.78524  0.78524  473110.037397  257184.923569
# 1      RENT  0.919397  0.78606  0.78606  472206.278174  257095.600781
#
# score      MAPE
# 0       0.26294
# 1      0.263026

# %%
p = sns.barplot(data=score_df, x='score', y='train')
p.set_title('Train Score')
for i in range(len(score_df)):
    p.text(i,param_df.train[i]/2,str(round(param_df.train[i],2)),
           fontdict=dict(color='white'),
          horizontalalignment='center')
plt.xticks(rotation=-20)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [16], in <cell line: 1>()
# ----> 1 p = sns.barplot(data=score_df, x='score', y='train')
#       2 p.set_title('Train Score')
#       3 for i in range(len(score_df)):
#
# NameError: name 'sns' is not defined
