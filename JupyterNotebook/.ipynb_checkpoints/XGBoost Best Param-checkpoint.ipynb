# %% [markdown]
# This notebook exists to mainly find out the best model used for prediction.

# %%
import pandas as pd

from xgboost import XGBRegressor

from sklearn.model_selection import train_test_split, GridSearchCV

from sklearn.metrics import r2_score, mean_absolute_error, mean_squared_error, mean_absolute_percentage_error

import seaborn as sns
sns.set(font_scale=1.2)
import matplotlib.pyplot as plt
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\scipy\__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.3
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %% [markdown]
# SALE DATA

# %%
sale_df = pd.read_csv('../data/iProperty_sale_to_be_trained.csv')

sale_df.drop(['name','psf','area'], axis=1, inplace=True)

for col in ['price']:
    q_low = sale_df[col].quantile(0.01)
    q_hi  = sale_df[col].quantile(0.99)
    sale_df = sale_df[(sale_df[col] < q_hi) & (sale_df[col] > q_low)]
    
one_hot = pd.get_dummies(sale_df[['district','state','type','details']])
sale_df = sale_df.join(one_hot).drop(['district','state','type','details'], axis=1)

sale_x = sale_df.drop(['price'],axis=1)
sale_y = sale_df['price']

sale_x_train, sale_x_test, sale_y_train, sale_y_test = train_test_split(sale_x, sale_y, test_size=0.2)

# %% [markdown]
# RENT DATA

# %%
rent_df = pd.read_csv('../data/iProperty_rent_to_be_trained.csv')

rent_df.drop(['name','psf','area'], axis=1, inplace=True)

for col in ['price']:
    q_low = rent_df[col].quantile(0.01)
    q_hi  = rent_df[col].quantile(0.99)
    rent_df = rent_df[(rent_df[col] < q_hi) & (rent_df[col] > q_low)]
    
one_hot = pd.get_dummies(rent_df[['district','state','type','details']])
rent_df = rent_df.join(one_hot).drop(['district','state','type','details'], axis=1)

rent_x = rent_df.drop(['price'],axis=1)
rent_y = rent_df['price']

rent_x_train, rent_x_test, rent_y_train, rent_y_test = train_test_split(rent_x, rent_y, test_size=0.2)

# %% [markdown]
# ### XGB Regressor

# %%
xg_hyperparameters = {
    'n_estimators': [300],
    'max_depth': [5],
    'eta': [0.2],
    'subsample': [0.8],
    'colsample_bytree' : [0.9],
    'alpha': [0.0,0.1,0.2],
    'lambda': [1.0,1.1,1.2]
}

# %%
xg_score = {
    'score':['R2','RMSE','MAE','MAPE']
}

# %% [markdown]
# on SALE DATA

# %%
# model_s = GridSearchCV(estimator=XGBRegressor(), param_grid=xg_hyperparameters, cv=3, n_jobs=-1, verbose=4)
# model_s.fit(sale_x_train, sale_y_train)

# xgs_best_params = model_s.best_params_
# display(xgs_best_params)

# pd.DataFrame.from_dict(model_s.cv_results_).sort_values(['mean_test_score','std_test_score'],ascending=False).T
# Out:
# Fitting 3 folds for each of 9 candidates, totalling 27 fits
# {'alpha': 0.2,
#  'colsample_bytree': 0.9,
#  'eta': 0.2,
#  'lambda': 1.0,
#  'max_depth': 5,
#  'n_estimators': 300,
#  'subsample': 0.8}
#                                                                         6  \
# mean_fit_time                                                   54.238299
# std_fit_time                                                     0.548624
# mean_score_time                                                  0.302934
# std_score_time                                                    0.04572
# param_alpha                                                           0.2
# param_colsample_bytree                                                0.9
# param_eta                                                             0.2
# param_lambda                                                          1.0
# param_max_depth                                                         5
# param_n_estimators                                                    300
# param_subsample                                                       0.8
# params                  {'alpha': 0.2, 'colsample_bytree': 0.9, 'eta':...
# split0_test_score                                                0.802114
# split1_test_score                                                0.779795
# split2_test_score                                                0.791047
# mean_test_score                                                  0.790985
# std_test_score                                                   0.009111
# rank_test_score                                                         1
#
#                                                                         3  \
# mean_fit_time                                                   47.750378
# std_fit_time                                                     0.286025
# mean_score_time                                                  0.213209
# std_score_time                                                   0.003773
# param_alpha                                                           0.1
# param_colsample_bytree                                                0.9
# param_eta                                                             0.2
# param_lambda                                                          1.0
# param_max_depth                                                         5
# param_n_estimators                                                    300
# param_subsample                                                       0.8
# params                  {'alpha': 0.1, 'colsample_bytree': 0.9, 'eta':...
# split0_test_score                                                0.802114
# split1_test_score                                                0.779795
# split2_test_score                                                0.791047
# mean_test_score                                                  0.790985
# std_test_score                                                   0.009111
# rank_test_score                                                         2
#
#                                                                         0  \
# mean_fit_time                                                   37.960841
# std_fit_time                                                     0.097673
# mean_score_time                                                  0.206311
# std_score_time                                                   0.015445
# param_alpha                                                           0.0
# param_colsample_bytree                                                0.9
# param_eta                                                             0.2
# param_lambda                                                          1.0
# param_max_depth                                                         5
# param_n_estimators                                                    300
# param_subsample                                                       0.8
# params                  {'alpha': 0.0, 'colsample_bytree': 0.9, 'eta':...
# split0_test_score                                                0.802114
# split1_test_score                                                0.779795
# split2_test_score                                                0.791047
# mean_test_score                                                  0.790985
# std_test_score                                                   0.009111
# rank_test_score                                                         3
#
#                                                                         7  \
# mean_fit_time                                                   53.783834
# std_fit_time                                                     0.856625
# mean_score_time                                                  0.276186
# std_score_time                                                   0.056938
# param_alpha                                                           0.2
# param_colsample_bytree                                                0.9
# param_eta                                                             0.2
# param_lambda                                                          1.1
# param_max_depth                                                         5
# param_n_estimators                                                    300
# param_subsample                                                       0.8
# params                  {'alpha': 0.2, 'colsample_bytree': 0.9, 'eta':...
# split0_test_score                                                0.794142
# split1_test_score                                                0.778379
# split2_test_score                                                0.788157
# mean_test_score                                                  0.786892
# std_test_score                                                   0.006497
# rank_test_score                                                         4
#
#                                                                         1  \
# mean_fit_time                                                   37.840828
# std_fit_time                                                     0.344493
# mean_score_time                                                  0.209646
# std_score_time                                                   0.013807
# param_alpha                                                           0.0
# param_colsample_bytree                                                0.9
# param_eta                                                             0.2
# param_lambda                                                          1.1
# param_max_depth                                                         5
# param_n_estimators                                                    300
# param_subsample                                                       0.8
# params                  {'alpha': 0.0, 'colsample_bytree': 0.9, 'eta':...
# split0_test_score                                                0.794142
# split1_test_score                                                0.778379
# split2_test_score                                                0.788157
# mean_test_score                                                  0.786892
# std_test_score                                                   0.006497
# rank_test_score                                                         5
#
#                                                                         4  \
# mean_fit_time                                                   48.097351
# std_fit_time                                                     0.276198
# mean_score_time                                                   0.20802
# std_score_time                                                   0.002253
# param_alpha                                                           0.1
# param_colsample_bytree                                                0.9
# param_eta                                                             0.2
# param_lambda                                                          1.1
# param_max_depth                                                         5
# param_n_estimators                                                    300
# param_subsample                                                       0.8
# params                  {'alpha': 0.1, 'colsample_bytree': 0.9, 'eta':...
# split0_test_score                                                0.794142
# split1_test_score                                                0.778379
# split2_test_score                                                0.788157
# mean_test_score                                                  0.786892
# std_test_score                                                   0.006497
# rank_test_score                                                         6
#
#                                                                         2  \
# mean_fit_time                                                   43.698117
# std_fit_time                                                     3.168613
# mean_score_time                                                  0.195229
# std_score_time                                                   0.005315
# param_alpha                                                           0.0
# param_colsample_bytree                                                0.9
# param_eta                                                             0.2
# param_lambda                                                          1.2
# param_max_depth                                                         5
# param_n_estimators                                                    300
# param_subsample                                                       0.8
# params                  {'alpha': 0.0, 'colsample_bytree': 0.9, 'eta':...
# split0_test_score                                                0.795826
# split1_test_score                                                0.775078
# split2_test_score                                                0.788576
# mean_test_score                                                  0.786493
# std_test_score                                                   0.008597
# rank_test_score                                                         7
#
#                                                                         8  \
# mean_fit_time                                                   30.233522
# std_fit_time                                                       0.3794
# mean_score_time                                                  0.125118
# std_score_time                                                   0.012912
# param_alpha                                                           0.2
# param_colsample_bytree                                                0.9
# param_eta                                                             0.2
# param_lambda                                                          1.2
# param_max_depth                                                         5
# param_n_estimators                                                    300
# param_subsample                                                       0.8
# params                  {'alpha': 0.2, 'colsample_bytree': 0.9, 'eta':...
# split0_test_score                                                0.795826
# split1_test_score                                                0.775078
# split2_test_score                                                0.788576
# mean_test_score                                                  0.786493
# std_test_score                                                   0.008597
# rank_test_score                                                         8
#
#                                                                         5
# mean_fit_time                                                   52.410389
# std_fit_time                                                     2.683843
# mean_score_time                                                  0.259764
# std_score_time                                                   0.056576
# param_alpha                                                           0.1
# param_colsample_bytree                                                0.9
# param_eta                                                             0.2
# param_lambda                                                          1.2
# param_max_depth                                                         5
# param_n_estimators                                                    300
# param_subsample                                                       0.8
# params                  {'alpha': 0.1, 'colsample_bytree': 0.9, 'eta':...
# split0_test_score                                                0.795826
# split1_test_score                                                0.775078
# split2_test_score                                                0.788576
# mean_test_score                                                  0.786493
# std_test_score                                                   0.008597
# rank_test_score                                                         9

# %%
xgs_best_params = {
    'alpha': 0.2,
    'colsample_bytree': 0.9,
    'eta': 0.2,
    'lambda': 1.0,
    'max_depth': 5,
    'n_estimators': 300,
    'subsample': 0.8
}

# %%
key = 'SALE'

xgs = XGBRegressor()
xgs.set_params(**xgs_best_params)
xgs.fit(sale_x_train,sale_y_train)
sale_y_pred = xgs.predict(sale_x_test)

xg_score[key] = []
xg_score[key].append(r2_score(sale_y_test,sale_y_pred))
xg_score[key].append(mean_squared_error(sale_y_test,sale_y_pred, squared=False))
xg_score[key].append(mean_absolute_error(sale_y_test,sale_y_pred))
xg_score[key].append(mean_absolute_percentage_error(sale_y_test,sale_y_pred))

xg_score
# Out:
# {'score': ['R2', 'RMSE', 'MAE', 'MAPE'],
#  'SALE': [0.7910695262837159,
#   461929.0398833698,
#   249493.1873462225,
#   0.25942696464609116]}

# %% [markdown]
# on RENT DATA

# %%
# model_r = GridSearchCV(estimator=XGBRegressor(), param_grid=xg_hyperparameters, cv=3, n_jobs=-1, verbose=4)
# model_r.fit(sale_x_train, sale_y_train)

# xgr_best_params = model_r.best_params_
# display(xgr_best_params)

# pd.DataFrame.from_dict(model_r.cv_results_).sort_values(['mean_test_score','std_test_score'],ascending=False).T
# Out:
# Fitting 3 folds for each of 9 candidates, totalling 27 fits
# {'alpha': 0.2,
#  'colsample_bytree': 0.9,
#  'eta': 0.2,
#  'lambda': 1.0,
#  'max_depth': 5,
#  'n_estimators': 300,
#  'subsample': 0.8}
#                                                                         6  \
# mean_fit_time                                                   72.205383
# std_fit_time                                                      1.65986
# mean_score_time                                                  0.291701
# std_score_time                                                   0.070722
# param_alpha                                                           0.2
# param_colsample_bytree                                                0.9
# param_eta                                                             0.2
# param_lambda                                                          1.0
# param_max_depth                                                         5
# param_n_estimators                                                    300
# param_subsample                                                       0.8
# params                  {'alpha': 0.2, 'colsample_bytree': 0.9, 'eta':...
# split0_test_score                                                0.802114
# split1_test_score                                                0.779795
# split2_test_score                                                0.791047
# mean_test_score                                                  0.790985
# std_test_score                                                   0.009111
# rank_test_score                                                         1
#
#                                                                         3  \
# mean_fit_time                                                     60.8685
# std_fit_time                                                     0.652447
# mean_score_time                                                  0.260527
# std_score_time                                                   0.011357
# param_alpha                                                           0.1
# param_colsample_bytree                                                0.9
# param_eta                                                             0.2
# param_lambda                                                          1.0
# param_max_depth                                                         5
# param_n_estimators                                                    300
# param_subsample                                                       0.8
# params                  {'alpha': 0.1, 'colsample_bytree': 0.9, 'eta':...
# split0_test_score                                                0.802114
# split1_test_score                                                0.779795
# split2_test_score                                                0.791047
# mean_test_score                                                  0.790985
# std_test_score                                                   0.009111
# rank_test_score                                                         2
#
#                                                                         0  \
# mean_fit_time                                                   58.262788
# std_fit_time                                                     0.340895
# mean_score_time                                                  0.221194
# std_score_time                                                   0.012909
# param_alpha                                                           0.0
# param_colsample_bytree                                                0.9
# param_eta                                                             0.2
# param_lambda                                                          1.0
# param_max_depth                                                         5
# param_n_estimators                                                    300
# param_subsample                                                       0.8
# params                  {'alpha': 0.0, 'colsample_bytree': 0.9, 'eta':...
# split0_test_score                                                0.802114
# split1_test_score                                                0.779795
# split2_test_score                                                0.791047
# mean_test_score                                                  0.790985
# std_test_score                                                   0.009111
# rank_test_score                                                         3
#
#                                                                         7  \
# mean_fit_time                                                   69.849398
# std_fit_time                                                     9.598805
# mean_score_time                                                   0.38479
# std_score_time                                                    0.07403
# param_alpha                                                           0.2
# param_colsample_bytree                                                0.9
# param_eta                                                             0.2
# param_lambda                                                          1.1
# param_max_depth                                                         5
# param_n_estimators                                                    300
# param_subsample                                                       0.8
# params                  {'alpha': 0.2, 'colsample_bytree': 0.9, 'eta':...
# split0_test_score                                                0.794142
# split1_test_score                                                0.778379
# split2_test_score                                                0.788157
# mean_test_score                                                  0.786892
# std_test_score                                                   0.006497
# rank_test_score                                                         4
#
#                                                                         1  \
# mean_fit_time                                                   57.907141
# std_fit_time                                                     0.058314
# mean_score_time                                                  0.256186
# std_score_time                                                   0.023051
# param_alpha                                                           0.0
# param_colsample_bytree                                                0.9
# param_eta                                                             0.2
# param_lambda                                                          1.1
# param_max_depth                                                         5
# param_n_estimators                                                    300
# param_subsample                                                       0.8
# params                  {'alpha': 0.0, 'colsample_bytree': 0.9, 'eta':...
# split0_test_score                                                0.794142
# split1_test_score                                                0.778379
# split2_test_score                                                0.788157
# mean_test_score                                                  0.786892
# std_test_score                                                   0.006497
# rank_test_score                                                         5
#
#                                                                         4  \
# mean_fit_time                                                   61.066529
# std_fit_time                                                     0.349761
# mean_score_time                                                  0.264302
# std_score_time                                                   0.033289
# param_alpha                                                           0.1
# param_colsample_bytree                                                0.9
# param_eta                                                             0.2
# param_lambda                                                          1.1
# param_max_depth                                                         5
# param_n_estimators                                                    300
# param_subsample                                                       0.8
# params                  {'alpha': 0.1, 'colsample_bytree': 0.9, 'eta':...
# split0_test_score                                                0.794142
# split1_test_score                                                0.778379
# split2_test_score                                                0.788157
# mean_test_score                                                  0.786892
# std_test_score                                                   0.006497
# rank_test_score                                                         6
#
#                                                                         2  \
# mean_fit_time                                                   58.907316
# std_fit_time                                                     1.340287
# mean_score_time                                                  0.247275
# std_score_time                                                     0.0464
# param_alpha                                                           0.0
# param_colsample_bytree                                                0.9
# param_eta                                                             0.2
# param_lambda                                                          1.2
# param_max_depth                                                         5
# param_n_estimators                                                    300
# param_subsample                                                       0.8
# params                  {'alpha': 0.0, 'colsample_bytree': 0.9, 'eta':...
# split0_test_score                                                0.795826
# split1_test_score                                                0.775078
# split2_test_score                                                0.788576
# mean_test_score                                                  0.786493
# std_test_score                                                   0.008597
# rank_test_score                                                         7
#
#                                                                         8  \
# mean_fit_time                                                   47.735302
# std_fit_time                                                     3.911734
# mean_score_time                                                  0.125773
# std_score_time                                                   0.022733
# param_alpha                                                           0.2
# param_colsample_bytree                                                0.9
# param_eta                                                             0.2
# param_lambda                                                          1.2
# param_max_depth                                                         5
# param_n_estimators                                                    300
# param_subsample                                                       0.8
# params                  {'alpha': 0.2, 'colsample_bytree': 0.9, 'eta':...
# split0_test_score                                                0.795826
# split1_test_score                                                0.775078
# split2_test_score                                                0.788576
# mean_test_score                                                  0.786493
# std_test_score                                                   0.008597
# rank_test_score                                                         8
#
#                                                                         5
# mean_fit_time                                                   69.113984
# std_fit_time                                                     5.464466
# mean_score_time                                                  0.315518
# std_score_time                                                   0.035014
# param_alpha                                                           0.1
# param_colsample_bytree                                                0.9
# param_eta                                                             0.2
# param_lambda                                                          1.2
# param_max_depth                                                         5
# param_n_estimators                                                    300
# param_subsample                                                       0.8
# params                  {'alpha': 0.1, 'colsample_bytree': 0.9, 'eta':...
# split0_test_score                                                0.795826
# split1_test_score                                                0.775078
# split2_test_score                                                0.788576
# mean_test_score                                                  0.786493
# std_test_score                                                   0.008597
# rank_test_score                                                         9

# %%
xgr_best_params = {
    'alpha': 0.2,
    'colsample_bytree': 0.9,
    'eta': 0.2,
    'lambda': 1.0,
    'max_depth': 5,
    'n_estimators': 300,
    'subsample': 0.8
}

# %%
key = 'RENT'

xgr = XGBRegressor()
xgr.set_params(**xgr_best_params)
xgr.fit(rent_x_train,rent_y_train)
rent_y_pred = xgr.predict(rent_x_test)

xg_score[key] = []
xg_score[key].append(r2_score(rent_y_test,rent_y_pred))
xg_score[key].append(mean_squared_error(rent_y_test,rent_y_pred, squared=False))
xg_score[key].append(mean_absolute_error(rent_y_test,rent_y_pred))
xg_score[key].append(mean_absolute_percentage_error(rent_y_test,rent_y_pred))

xg_score
# Out:
# {'score': ['R2', 'RMSE', 'MAE', 'MAPE'],
#  'SALE': [0.7910695262837159,
#   461929.0398833698,
#   249493.1873462225,
#   0.25942696464609116],
#  'RENT': [0.7488105590263479,
#   919.7237714836668,
#   557.8653661113827,
#   0.23702415058095366]}

# %%
xg_df = pd.DataFrame(xg_score).T
xg_df.columns = xg_df.iloc[0]
xg_df = xg_df[1:]
xg_df = xg_df.reset_index()
xg_df.rename(columns={'index':'data'}, inplace=True)
xg_df
# Out:
# score  data        R2           RMSE            MAE      MAPE
# 0      SALE   0.79107  461929.039883  249493.187346  0.259427
# 1      RENT  0.748811     919.723771     557.865366  0.237024

# %%
metric = 'R2'
p = sns.barplot(data=xg_df, x='data', y='R2')
p.set_title('{} Score'.format(metric))
for i in range(len(xg_df)):
    p.text(i,xg_df[metric][i]/2,str(round(xg_df[metric][i],2)),
           fontdict=dict(color='white'),
          horizontalalignment='center')
plt.xticks(rotation=-20)
# Out:
# (array([0, 1]), [Text(0, 0, 'SALE'), Text(1, 0, 'RENT')])

# %%
metric = 'RMSE'
p = sns.barplot(data=xg_df, x='data', y=metric)
p.set_title('{} Score'.format(metric))
for i in range(len(xg_df)):
    p.text(i,xg_df[metric][i]/2,str(round(xg_df[metric][i])),
           fontdict=dict(color='white'),
          horizontalalignment='center')
plt.xticks(rotation=-20)
# Out:
# (array([0, 1]), [Text(0, 0, 'SALE'), Text(1, 0, 'RENT')])

# %%
metric = 'MAE'
p = sns.barplot(data=xg_df, x='data', y=metric)
p.set_title('{} Score'.format(metric))
for i in range(len(xg_df)):
    p.text(i,xg_df[metric][i]/2,str(round(xg_df[metric][i])),
           fontdict=dict(color='white'),
          horizontalalignment='center')
plt.xticks(rotation=-20)
# Out:
# (array([0, 1]), [Text(0, 0, 'SALE'), Text(1, 0, 'RENT')])

# %%
metric = 'MAPE'
p = sns.barplot(data=xg_df, x='data', y=metric)
p.set_title('{} Score'.format(metric))
for i in range(len(xg_df)):
    p.text(i,xg_df[metric][i]/2,str(round(xg_df[metric][i],2)),
           fontdict=dict(color='white'),
          horizontalalignment='center')
plt.xticks(rotation=-20)
# Out:
# (array([0, 1]), [Text(0, 0, 'SALE'), Text(1, 0, 'RENT')])
